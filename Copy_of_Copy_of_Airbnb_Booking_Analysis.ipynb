# %% [markdown]
# <a href="https://colab.research.google.com/github/p0shivhare/AirBnb_Booking_Analysis/blob/main/Copy_of_Copy_of_Airbnb_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  AirBnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Piyush Shivhare
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The project involved analyzing data on Airbnb listings in New York City to gain insights into the market trends and customer preferences. The data was obtained from Inside Airbnb and contained information on the location, price, availability, and other features of the listings.
#
# To achieve the objectives, various visualizations were created, including scatter plots, heatmaps, and bar charts. The analysis revealed that the price of Airbnb listings is influenced by factors such as location, room type, and availability. Listings in Manhattan and Brooklyn tend to be more expensive than those in other neighborhoods, and entire homes and private rooms are more expensive than shared rooms.
#
# The analysis also showed that the majority of Airbnb listings are concentrated in Manhattan and Brooklyn, with fewer listings in the Bronx, Queens, and Staten Island. Additionally, private rooms have the highest availability in Staten Island, while shared rooms have the lowest availability.
#
# Furthermore, the analysis identified the busiest Airbnb hosts and the types of rooms they offer. Dona, Ji, Maya, Carol, and Danielle are the busiest hosts, and they offer entire homes and private rooms, which are popular among the majority of Airbnb guests.
#
# Overall, the analysis provides insights into the Airbnb market in New York City, which can be useful for hosts, guests, and Airbnb itself. Hosts can use the information to determine the type of room to offer in different neighborhoods based on the demand and availability of that room type. Guests can use the information to choose where to stay based on their preferences and budget. Airbnb can use the information to optimize their business strategy and balance the popularity of popular room types with other offerings on their platform.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://p0shivhare.github.io/AirBnb_Booking_Analysis/

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The potential business problem that could be addressed is how to utilize the data provided by Airbnb listings to improve the platform's overall performance and profitability.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business problem is that Airbnb needs to improve the user experience and satisfaction by providing clear and accurate information about the listings available on the platform. Users have varying preferences and requirements, such as budget, location, and occupancy, and Airbnb needs to ensure that users are able to easily find listings that match their needs. By addressing this business problem, Airbnb can increase the number of bookings and repeat customers, which can ultimately lead to increased revenue and profitability.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df= pd.read_csv('/content/drive/MyDrive/Almabeller/Python/Capstone 1/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#Dataset's Last 5 Rows
df.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
row, column= df.shape

print('Number of rows: {}'.format(row))
print('Number of columns: {}'.format(column))
# Out:
# Number of rows: 48895
# Number of columns: 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
num_duplicates= df.duplicated().sum()

# Print the duplicate value
if num_duplicates==0:
  print('There is No Duplicate Value in DataFrame')
else:
  print('Number of Duplicte Values : {}'.format(num_duplicates))
# Out:
# There is No Duplicate Value in DataFrame

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_value= df.isnull().sum()
print(null_value)
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values

plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cmap='Blues')

plt.title('Missing values in the Airbnb NYC 2019 dataset')
plt.xlabel('Columns')
plt.ylabel('Missing Values')

# Display the plot
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The DataFrame is all out the distribution of every Airbnb listing based on their location in NYC, including their price range, room type listing name, and other related factors.
# The DataFrame contains 48895 rows and 16 collumns.
# The Description of the Dataset-
#
# There is no Duplicate Value in DataFrame
#
# There is some missing/null values in DataFrame-
#
#
# In name column 16 null values, host_name 21 null values, last_review 10052 and also in reviews_per_month 10052 null values. Null values are visualized by missingno matrix all white line representing null value in DataFrame.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
for i, col in enumerate(df.columns.tolist()):
    print(i+1, col)
# Out:
# 1 id
# 2 name
# 3 host_id
# 4 host_name
# 5 neighbourhood_group
# 6 neighbourhood
# 7 latitude
# 8 longitude
# 9 room_type
# 10 price
# 11 minimum_nights
# 12 number_of_reviews
# 13 last_review
# 14 reviews_per_month
# 15 calculated_host_listings_count
# 16 availability_365

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The file "Airbnb NYC 2019.csv" contains a dataset of Airbnb listings in New York City during the year 2019. The data includes various attributes such as the listing ID and name, host ID and name, neighborhood,neighborhood group, latitude and longitude coordinates, room type, minimum and maximum number of nights, availability, number of reviews, and overall rating by guests. This dataset can be used to analyze various trends in the Airbnb market in New York City, and to explore the factors that affect the success of individual listings.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Filling the null values
df["name"].fillna("Unavailable", inplace= True)
df["host_name"].fillna("Unavailable", inplace= True)

# %%
df["last_review"].fillna("0", inplace= True)
df["reviews_per_month"].fillna("0", inplace= True)

# %%
# availability_360 column

round((len(df[df['availability_365']==0])))
# Out:
# 17533

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# *  We can see that some of the sells are null in name and host_name column in the DataFrame, We can replace them with 'Unavailable'.
#
# * For Nan Values in column reviews_per_month, and last review,replacing Nan with 0.
#
# * We can see that the availability column has a minimum value of 0 for 17533 entries, which is quite surprising. This means that around 17533 entries of the data has an extreme case where the apartments have 0 availability days.
#  This is not practical to detect which apartments have a genuine 0 availability, so we will not change this column. Changing this column can lead to manipulating apartments that are usually busy.
#
# * The price of a listing on Airbnb varies on different factors, including location, room type, neighborhood, season, and other factors. Therefore, a price of $10,000 or higher may not necessarily be an outlier and cannot be discarded without analyzing the data and context.
# Additionally, there are a few values with 0 in the 'price' column. This could be due to dynamic pricing or the host's decision not to share the price with Airbnb.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 ***Top-10 Apartment listing by Host Name***

# %%
# Number of apartment according to Host Name
num_apart= pd.value_counts(df.host_name)[:10]
num_apart = num_apart.rename_axis('Host Name').reset_index(name='Number of Apartments')


num_apart.plot.bar()
plt.xlabel("Host Name")
plt.ylabel("Number of Apartment")
plt.title("Number of apartment according to name")
plt.show()

num_apart
# Out:
#       Host Name  Number of Apartments
# 0       Michael                   417
# 1         David                   403
# 2  Sonder (NYC)                   327
# 3          John                   294
# 4          Alex                   279
# 5    Blueground                   232
# 6         Sarah                   227
# 7        Daniel                   226
# 8       Jessica                   205
# 9         Maria                   204

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Based on my assumption, although the data seemed similar at first glance, we obtained different results when we plotted it. To make comparisons easier, I created a bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# According to the Chart 1 Michael having most number of apartments... But in chart 2....

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Not any.

# %% [markdown]
# #### Chart - 2 (Top-10 Apartment according to Host ID)

# %%
# Number of apartment according to Host IDs

top_host_ids = df.groupby(['host_id', 'host_name'])['id'].count().reset_index().sort_values(by='id', ascending=False).head(10)
top_host_ids=top_host_ids.rename(columns={'id': 'number_of_listings'})
# Plotting the results in a bar chart
top_host_ids.plot.bar(x='host_name', y='number_of_listings')
plt.xlabel("Host Name")
plt.ylabel("Number of Apartment")
plt.title("Number of apartment according to ID")
plt.show()

# Print the top 10 hosts along with their number of listings
print(top_host_ids)
# Out:
#          host_id          host_name  number_of_listings
# 34646  219517861       Sonder (NYC)                 327
# 29407  107434423         Blueground                 232
# 19574   30283594               Kara                 121
# 31079  137358866             Kazuya                 103
# 14436   16098958     Jeremy & Laura                  96
# 12806   12243051             Sonder                  96
# 25662   61391963  Corporate Housing                  91
# 17091   22541573                Ken                  87
# 33868  200380610            Pranjal                  65
# 3044     1475015               Mike                  52

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Based on my assumption, although the data seemed similar at first glance, we obtained different results when we plotted it. To make comparisons easier, I created a bar graph.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We are plotted two diffrent charts for getting the result which hosts are having the highest number of apartments?
#
# We can see that in the first chart the host name Michael is appearing 417 times in the host_name column, so this might imply that Michael has the highest number of rooms.
#
# However, in the second chart from the host_id column, it is showing the highest appearance of host_id of Sonder is 327.
#
# This clearly implies that there can be multiple persons who may have the same name, which is why we are getting a different highest appearance in host_name as compared to host_id

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact for Airbnb. By identifying which hosts have the highest number of apartments, Airbnb can focus on building relationships with those hosts and incentivizing them to continue listing their properties on the platform. Additionally, by understanding which hosts are most successful, Airbnb can provide guidance and support to other hosts to help them improve their performance and potentially increase the number of listings on the platform. This can lead to increased revenue for Airbnb and a better user experience for guests, ultimately resulting in a positive impact on the business.
#
# For guests, this information can help them make more informed decisions about which hosts to choose and which areas to stay in. They can compare the pricing and availability of apartments from the hosts with the highest number of listings and choose the best option for their budget and needs.

# %% [markdown]
# #### Chart - 3 ***Listings By Location (Neighbourhood Group)***

# %%
# Listing By Neighborhood Group (Location)
listing_by_ng= pd.value_counts(df["neighbourhood_group"])

listing_by_ng.plot(kind='pie',autopct='%1.1f%%')
plt.title('Number of Listings by Neighborhood Group')
plt.ylabel('')
plt.show()

listing_by_ng
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, we chose to use a pie chart to display the distribution of Airbnb listings across the different neighborhood groups. By using a pie chart, we can easily compare the size of each slice, which represents the number of listings in each neighborhood group, and identify which neighborhood groups have the most and least number of listings. This visual representation is simple to understand and can help to quickly identify any patterns or trends in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Manhattan has the highest number of listings with 44.3% of the total listings in the dataset.
# * Brooklyn has the second-highest number of listings with 41.1% of the total listings.
# * Queens has the third-highest number of listings with 11.6% of the total listings.
# * The Bronx and Staten Island have the lowest number of listings with less than 2% each.
#
# Overall, the chart shows that the majority of listings in the dataset are located in Manhattan and Brooklyn, which suggests that these neighbourhood groups may be more popular among Airbnb users in New York City.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Analyzing which neighborhoods groups have the highest number of listings can provide valuable insights for Airbnb to improve its business strategy. By understanding which neighborhoods grpups are most popular among users, Airbnb can focus its marketing efforts and enhance the user experience in those areas. Additionally, by identifying neighborhoods grpups with lower numbers of listings, Airbnb can explore ways to increase the number of listings in those areas and expand its reach to new markets. This data can help Airbnb to make informed decisions to improve its business growth and profitability.
#
# For users, the analysis can help them make more informed decisions about where to stay and how much to charge for their listings.

# %% [markdown]
# #### Chart - 4 (Number of listing in each Neighbourhood Group By Room Type)

# %%
#  count the number of listings in each group
grouped_data = df.groupby(['neighbourhood_group', 'room_type'])['id'].count().reset_index(name='count')

plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood_group', y='count', hue='room_type', data=grouped_data)
plt.title('Distribution of Room Types by Neighbourhood Group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Listings')
plt.show()

grouped_data.reset_index()
# Out:
#     index neighbourhood_group        room_type  count
# 0       0               Bronx  Entire home/apt    379
# 1       1               Bronx     Private room    652
# 2       2               Bronx      Shared room     60
# 3       3            Brooklyn  Entire home/apt   9559
# 4       4            Brooklyn     Private room  10132
# 5       5            Brooklyn      Shared room    413
# 6       6           Manhattan  Entire home/apt  13199
# 7       7           Manhattan     Private room   7982
# 8       8           Manhattan      Shared room    480
# 9       9              Queens  Entire home/apt   2096
# 10     10              Queens     Private room   3372
# 11     11              Queens      Shared room    198
# 12     12       Staten Island  Entire home/apt    176
# 13     13       Staten Island     Private room    188
# 14     14       Staten Island      Shared room      9

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By grouping the data by 'neighbourhood_group' and 'room_type', we can see the number of listings for each combination of neighborhood and room type. The chart allows us to compare the distribution of room types across neighborhoods, as well as identify any neighborhoods with a particularly high or low number of listings

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Chart shows number of listings for each room type (entire home/apt, private room, and shared room) in NYC
# * Brooklyn has highest number of private room listings with 10,132, followed by Manhattan with 7,982 private room listings
# * Manhattan has highest number of entire home/apt listings with 13,199, followed by Brooklyn with 9,559 entire home/apt listings
# * Shared room listings are least common, with Staten Island having least number of listings for shared rooms with only 9, followed by the Bronx with 60 shared room listings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from this chart can be useful for Airbnb hosts to better understand the preferences of guests in different neighborhoods and adjust their listings accordingly. It can also be helpful for Airbnb to understand the demand for different types of rooms in different neighborhood groups and tailor their marketing strategies accordingly. Overall, the insights gained from this chart can have a positive impact on business growth.

# %% [markdown]
# #### Chart - 5 (Listings by room type)

# %%
# AirBnb Listing by room type
property_type = df.groupby('room_type')['id'].count()

# create pie chart
plt.pie(property_type, labels=property_type.index, autopct='%1.1f%%')
plt.title('Distribution of Airbnb Listings by Property Type')
plt.show()

property_type
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: id, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# By grouping the data by 'neighbourhood_group' and 'room_type', we can see the number of listings for each combination of neighborhood and room type. The chart allows us to compare the distribution of room types across neighborhoods, as well as identify any neighborhoods with a particularly high or low number of listings

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from this data shows that among the three property types offered by Airbnb, "Entire home/apt" and "Private room" are the most popular, with 25409 and 22326 listings respectively, while "Shared room" has the lowest number of listings with only 1160.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Most Airbnb guests prefer to book entire homes or private rooms rather than sharing a room with other guests. This insight can be useful for hosts and businesses to understand the demand for different types of accommodations and tailor their offerings accordingly to attract more guests and increase their revenue.
# * Understanding the demand for different types of accommodations can help hosts and businesses make data-driven decisions about their listings and pricing strategies.
# * By focusing on the most popular property types, hosts and businesses can increase their occupancy rates and revenue potential.
# * However, hosts and businesses may need to consider offering a mix of property types to cater to a wider range of guest preferences and needs.
# *Overall, the insights gained from the chart can have a positive impact on business growth and success on the Airbnb platform.

# %% [markdown]
# #### Chart - 6 (Top-10 Neighbouhoos which are having highest number of listing for AirBnb)

# %%
# Top-10 Neighbouhoos which are having highet number of listing for AirBnb.
top_10_nh= pd.value_counts(df['neighbourhood']).sort_values(ascending=False).head(10)

sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_nh, y=top_10_nh.index, palette='Blues_r')
plt.title('Top 10 Neighborhoods with the Most Airbnb Listings')
plt.xlabel('Number of Listings')
plt.show()

top_10_nh
# Out:
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: neighbourhood, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I would like to do is show a bar chart that displays the top 10 neighborhoods with the highest number of apartments listed on Airbnb. This will allow me to easily visualize which neighborhoods have the most listings and compare them to others.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Airbnb having maximum number of appartments for Williamsburg with 3920 numbers of appartments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The top 10 neighborhoods in New York City with the most Airbnb listings can help property owners to focus their investments on areas with high demand for short-term rentals. However, if there are too many listings in a neighborhood, it can lead to stiff competition, lower occupancy rates, and falling prices.

# %% [markdown]
# #### Chart - 7 (Price Distribution)

# %%
# Distriubtion of Price
# Removeing rows where the price is 0
df1 = df[df["price"] != 0]

# Histogram of the price data

plt.hist(df1["price"], bins=50)
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is a suitable chart for analyzing the distribution of a continuous variable such as price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The price distribution is right-skewed, indicating that there are more listings with lower prices and fewer listings with higher prices. The majority of listings are priced under 500, with a significant drop-off in the number of listings above this price point. There are some listings with very high prices, with a small number of listings priced above 2000 per night.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from analyzing the price distribution can help hosts and property managers to develop effective pricing strategies, stay competitive, and increase revenue.
# However, hosts and property managers need to be careful not to price their listings too high or base their pricing strategy solely on outliers, which may result in negative growth.

# %% [markdown]
# #### Chart - 8 (Top 15 most expensive neighbourhoods)

# %%
# Excluding Values which was 0
df2 = df[df['price']!=0]

# Top 15 Values
top_15by_price= df2.groupby('neighbourhood')['price'].mean().sort_values(ascending=False)[:15]

# Plotting a Bar Chart
plt.figure(figsize=(12, 8))
top_15by_price.plot.bar()
plt.title('Top 15 Most Expensive Neighbourhoods in Airbnb Listings')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Price')
plt.show()

top_15by_price
# Out:
# neighbourhood
# Fort Wadsworth       800.000000
# Woodrow              700.000000
# Tribeca              490.638418
# Sea Gate             487.857143
# Riverdale            442.090909
# Prince's Bay         409.500000
# Battery Park City    367.557143
# Flatiron District    341.925000
# Randall Manor        336.000000
# NoHo                 295.717949
# SoHo                 287.103352
# Midtown              282.719094
# Neponsit             274.666667
# West Village         267.682292
# Greenwich Village    263.405612
# Name: price, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart is an effective way to compare the average price of different neighborhoods

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most expensive neighbourhood in the Airbnb listings is Fort Wadsworth with an average price of around 800 dollars.
# Woodrow,Tribeca, SeaGate, Riverdale, and Prince's Bay are some of the other expensive neighbourhoods in the Airbnb listings.
# Most of the expensive neighbourhoods are located in Fort Wadsworth.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight could be useful for travelers who are looking for high-end and luxurious accommodations, as well as for Airbnb hosts who are interested in renting out properties in these expensive neighborhoods.

# %% [markdown]
# #### Chart - 9 (Top 15 least expensive neighbourhoods)

# %%
# Top-15 Values
least_15by_price= df2.groupby('neighbourhood')['price'].mean().sort_values(ascending=True)[:15]

# Plotting a Bar Chart
plt.figure(figsize=(12, 8))
least_15by_price.plot.bar()
plt.title('Top 15 Least Expensive Neighbourhoods in Airbnb Listings')
plt.xlabel('Neighbourhood')
plt.ylabel('Average Price')
plt.show()

least_15by_price
# Out:
# neighbourhood
# Bull's Head       47.333333
# Hunts Point       50.500000
# Tremont           51.545455
# Soundview         53.466667
# New Dorp          57.000000
# Bronxdale         57.105263
# New Dorp Beach    57.400000
# Grant City        57.666667
# Concord           58.192308
# Mount Eden        58.500000
# Corona            59.171875
# Woodlawn          60.090909
# Castle Hill       63.000000
# Borough Park      63.066176
# Olinville         64.000000
# Name: price, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart helps us to identify any patterns or trends in the data that can inform business decisions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The neighbourhoods with the lowest average prices for listings are Bull's Head, Hunts Point, Tremont, Soundview, and New Dorp. These neighbourhoods are relatively less expensive than other neighbourhoods in New York City and might be a good option for budget travellers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This chart can provide insights for budget travelers or those looking for affordable accommodation options. The chart can also be useful for hosts who want to set competitive prices and attract budget-conscious travelers.

# %% [markdown]
# #### Chart - 10 (Relationship Between Number of Reviews and Price)

# %%
# Relationship Between Number of Reviews and Price
plt.figure(figsize=(15,8))
plt.scatter(df['number_of_reviews'], df['price'], alpha=0.5)
plt.title('Relationship Between Number of Reviews and Price')
plt.xlabel('Number of Reviews')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It can show the correlation between two continuous variables, making it useful for identifying trends and patterns in data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The Queens neighborhood group has the highest number of reviews among all the neighborhood groups, followed by Manhattan, Brooklyn, Staten Island, and the Bronx.
# * This indicates that Brooklyn and Manhattan have a higher number of Airbnb listings and are more popular among guests, leading to more reviews

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the scatter plot can help businesses create a positive impact by informing pricing and marketing strategies for Airbnb listings. However, if businesses solely focus on the relationship between the number of reviews and the price of a listing, it could lead to negative growth as they may overlook other factors that contribute to pricing and demand. Therefore, businesses should use the insights gained from the scatter plot as part of a comprehensive strategy that takes into account multiple factors specific to their market and customer base.

# %% [markdown]
# #### Chart - 11 (Relationship Between Number of Reviews and Area)

# %%
areas_reviews = df.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
area = areas_reviews['neighbourhood_group']
review = areas_reviews['number_of_reviews']

fig = plt.figure(figsize = (10, 5))
 # creating the bar plot
plt.bar(area, review,width = 0.4)
 
plt.xlabel("area")
plt.ylabel("review")
plt.title("Area vs Number of reviews")
plt.show()

areas_reviews
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx                321
# 1            Brooklyn                488
# 2           Manhattan                607
# 3              Queens                629
# 4       Staten Island                333

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked the specific chart because it shows the clear comparison of the number of reviews in each neighborhood group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Queens neighborhood group has received the maximum number of reviews among all the neighborhood groups, followed by Manhattan, Brooklyn, Staten Island, and the Bronx. This indicates that Brooklyn and Manhattan have a higher number of Airbnb listings and are more popular among guests, leading to more reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the chart can potentially have a positive business impact for Airbnb and its users. By analyzing the number of reviews per neighbourhood group, Airbnb can identify areas where there is high demand and interest from customers. This can help Airbnb to focus on marketing and promoting listings in these areas, and potentially attract more hosts to list their properties, which could lead to an increase in the number of bookings and revenue for both Airbnb and hosts.

# %% [markdown]
# #### Chart - 12 (Average Price of Each Room Type in Neighbourhood Group)

# %%
# applying groupby over 'neighbourhood_groups' and 'room_type' 
# then applying mean of price  and unstacking for clear visualization
price = df[df['price'] != 0]['price']
avg_price_df = df[df['price'] != 0].groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()


avg_price_df.plot.bar(figsize=(15,5),
ylabel='Average Price calculated',
xlabel='Neighbourhood Group')
plt.show()

avg_price_df
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.506596     66.890937    59.800000
# Brooklyn                  178.346202     76.545428    50.773723
# Manhattan                 249.257994    116.776622    88.977083
# Queens                    147.050573     71.762456    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart was chosen as it effectively shows the average preferred price by customers according to the neighborhood group for each category of room type. It allows for easy comparison between the different room types and neighborhoods, highlighting any significant differences in pricing trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The average price of an entire home/apt is the highest across all neighborhood groups, with Manhattan having the highest average price of 249.24, followed by Brooklyn with an average price of 178.33.
# * Private rooms have a lower average price compared to entire homes/apt, with Manhattan having the highest average price of 116.78, followed by Brooklyn with an average price of 76.50.
# * Shared rooms have the lowest average price across all neighborhood groups, with Manhattan having the highest average price of $88.98, followed by Queens with an average price of 69.02.
# * Among all neighborhood groups, the Bronx has the lowest average price for entire homes/apt, private rooms, and shared rooms.
# * As we can see from the chart, customers generally prefer private rooms and entire homes/apartments over shared rooms, and are willing to pay more for them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart is useful in comparing the average price of different room types across different neighbourhood groups. It can help Airbnb hosts to understand the market trends and set competitive prices for their listings. The chart can also help potential guests to understand the expected prices for different room types in different neighbourhoods, allowing them to plan their trips and budget accordingly.

# %% [markdown]
# #### Chart - 13 ( Revenue Generated by diffrent Neighborhoods and Propery type)

# %%
# Calculate revenue by multiplying price and minimum nights
df['revenue'] = df['price'] * df['minimum_nights']

# Group data by neighbourhood group and room type and sum revenue
revenue_by_neighborhood = df.groupby(['neighbourhood_group', 'room_type'])['revenue'].sum().reset_index()

# Plot bar chart of revenue by neighborhood and room type
plt.figure(figsize=(12, 8))
sns.barplot(x='neighbourhood_group', y='revenue', hue='room_type', data=revenue_by_neighborhood)
plt.title('Revenue Generated by Different Neighborhoods and Property Types')
plt.xlabel('Neighborhood')
plt.ylabel('Revenue')
plt.show()

revenue_by_neighborhood
# Out:
#    neighbourhood_group        room_type   revenue
# 0                Bronx  Entire home/apt    226349
# 1                Bronx     Private room    143670
# 2                Bronx      Shared room      8385
# 3             Brooklyn  Entire home/apt  11145804
# 4             Brooklyn     Private room   4952427
# 5             Brooklyn      Shared room    124176
# 6            Manhattan  Entire home/apt  34103936
# 7            Manhattan     Private room   6548968
# 8            Manhattan      Shared room    288125
# 9               Queens  Entire home/apt   2344854
# 10              Queens     Private room   2675540
# 11              Queens      Shared room     41156
# 12       Staten Island  Entire home/apt    160695
# 13       Staten Island     Private room     37068
# 14       Staten Island      Shared room      1187

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chart shows the revenue generated by different neighborhoods and property types, helping to identify the most profitable areas and property types for the business.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that Manhattan generates the highest revenue, followed by Brooklyn and Queens. Staten Island and the Bronx generate the least amount of revenue.
#
# We can also see that entire homes/apartments generate the highest revenue across all neighborhoods, followed by private rooms and shared rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This suggests that hosts may be able to generate more revenue by renting out entire homes/apartments, rather than individual rooms.
#
# Overall, this information can be useful for Airbnb hosts and businesses to identify neighborhoods and property types that are most lucrative for generating revenue.

# %% [markdown]
# #### Chart - 14 (Minumum Night Distribution)

# %%
# Plotting a histogram for analyzing minimum night
plt.hist(df["minimum_nights"], bins=50)
plt.xlabel("Minimum Nights")
plt.ylabel("Frequency")
plt.title("Distribution of Minimum Nights on Airbnb NYC")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the histogram chart to analyze the distribution of minimum nights because it is a useful chart to visualize the frequency distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the histogram of minimum nights, we can observe that the majority of the listings have a minimum stay requirement of less than 10 nights. There is also a significant number of listings that have a minimum stay requirement of 30 nights or more, indicating that they may be more suitable for longer-term stays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The histogram of minimum nights shows that most listings have a minimum stay requirement of less than 10 nights. The minumum number of listings require a minimum stay of 1 night, indicating that most hosts are willing to accommodate short-term stays. This information can help potential guests plan their trips accordingly and can also help hosts understand the expectations of their guests. However, it's important to note that there are still a significant number of listings with longer minimum stay requirements, which may affect the booking patterns and overall demand in certain areas.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Selecting numerical columns to create correlation matrix
num_cols = ['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']

# Correlation matrix
corr_matrix = df[num_cols].corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap of Airbnb NYC Dataset')
plt.show()
# Out:
# <ipython-input-30-1bc08442643b>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df[num_cols].corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Correlation Heatmap provides a useful overview of the relationships between different features in the dataset, and can help identify potential patterns and insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Correlation Heatmap is a visual representation of the correlation between different numerical features in the dataset.
#
# * Positive correlation = Red
# * Negative correlation = Blue
#
# The annotation in each cell shows the correlation coefficient value.
#
# * There is a positive correlation between the number of reviews and reviews per month.
# * There is a positive correlation between the availability of the listing and the number of reviews.
# * There is a negative correlation between the minimum number of nights a guest can book and the availability of the listing.
# * There is a positive correlation between the calculated host listings count and the availability of the listing.
#
# This information can be useful for understanding how different features are related to each other and identifying potential patterns or relationships in the data.

# %% [markdown]
# #### Chart - 16 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'availability_365']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Graphical representation of pairwise relationships in a dataset. It shows the scatter plot of each pair of variables along with the histograms of each variable along the diagonal. This helps in identifying the correlation between variables in the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the plotted scatter charts, we can see that there is no clear linear relationship between price and any of the other variables. However, there seems to be a slight negative correlation between price and availability in 365 days, which means that as availability increases, the price decreases slightly.

# %% [markdown]
# #### Chart - 17 (Visualizing the location of each apprtment using latitude and longitude values

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=df['longitude'],y=df['latitude'], hue=df['neighbourhood_group'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart provides a visual representation of the distribution of Airbnb listings across NYC

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# hat shows the distribution of Airbnb listings across the NYC map, with each dot representing a listing. The color of the dot corresponds to the neighborhood group in which the listing is located.
#
# From the scatter plot, we can see that the majority of the Airbnb listings are concentrated in Manhattan and Brooklyn, with fewer listings in the Bronx, Queens, and Staten Island. Additionally, we can see that listings in Manhattan tend to be more concentrated in the lower part of the island, while listings in Brooklyn are more spread out.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This information can be useful for both hosts and guests, as it can help hosts decide where to list their properties and guests choose where to stay based on their preferences and budget.
#
# Overall, this chart provides a visual representation of the distribution of Airbnb listings across NYC, which can help hosts and guests make informed decisions.

# %% [markdown]
# #### Chart - 18 (Average Avalability by Naighbourhood and Room Type)

# %%
# Avg availability by neighborhood and room type
availability = df.groupby(['neighbourhood_group', 'room_type'])['availability_365'].mean().reset_index()

# Pivot the data to prepare for heatmap
availability_pivot = availability.pivot('neighbourhood_group', 'room_type', 'availability_365')

# Create heatmap
sns.heatmap(availability_pivot, annot=True, fmt='.0f', cmap='YlGnBu')
plt.title('Average Availability by Neighborhood and Room Type')
plt.xlabel('Room Type')
plt.ylabel('Neighborhood')
plt.show()
# Out:
# <ipython-input-33-c517f08cedec>:5: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   availability_pivot = availability.pivot('neighbourhood_group', 'room_type', 'availability_365')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Heat map provide ease of visualization between two variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows the availability of listings in different neighborhoods and room types. The darker the color, the more listings available.
#
# The insights from the chart is that is there is high availability of private room in Staten Island and less avalibility of shared room in Staten Island.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This information can be useful for Airbnb hosts to determine the type of room to offer in different neighborhoods based on the demand and availability of that room type. It can also be useful for potential guests to determine which neighborhoods have a higher likelihood of finding available rooms.

# %% [markdown]
# #### Chart - 19 (Top-10 Busyest Hosts)

# %%
busiest_hosts = df.groupby(['host_name','host_id','room_type'])['number_of_reviews'].max().reset_index()
busiest_hosts = busiest_hosts.sort_values(by='number_of_reviews', ascending=False).head(10)
name = busiest_hosts['host_name']
reviews = busiest_hosts['number_of_reviews']

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(name, reviews, color ='maroon',
        width = 0.4)
 
plt.xlabel("Name of the Host")
plt.ylabel("Number of Reviews")
plt.title("Busiest Hosts")
plt.show()

busiest_hosts
# Out:
#       host_name   host_id        room_type  number_of_reviews
# 10279      Dona  47621202     Private room                629
# 17708        Jj   4734398     Private room                607
# 25566      Maya  37312959     Private room                543
# 6235      Carol   2369681     Private room                540
# 8947   Danielle  26432133     Private room                510
# 3950        Asa  12949460  Entire home/apt                488
# 37766     Wanda    792159     Private room                480
# 22499     Linda   2680820     Private room                474
# 8625       Dani     42273  Entire home/apt                467
# 2942     Angela  23591164     Private room                466

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar graphs are a valuable tool for visualizing the distribution of data, particularly when the data can be categorized into distinct groups or categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The busiest Airbnb hosts based on their listed room types are Dona, Ji, Maya, Carol, and Danielle. These hosts have listed their rooms as Entire home and Private room, which are popular choices among the majority of Airbnb guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# On the one hand, knowing which hosts are busiest based on their listed room types could provide insights into customer preferences and help Airbnb optimize their business strategy. For example, they could focus on recruiting more hosts who offer entire homes or private rooms, which are popular among guests. This could help increase customer satisfaction and retention, leading to positive business impact.
#
# On the other hand, there could be potential negative impact if Airbnb becomes too reliant on these hosts and does not diversify its offerings. If these hosts were to leave the platform or reduce their listings, it could lead to a decrease in supply and potentially negatively impact Airbnb's revenue and growth.
#
# Ultimately, the impact of this insight will depend on how Airbnb chooses to act on it and whether they are able to effectively balance the popularity of these room types with other offerings on their platfor

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The potential solution to the business objective of increasing revenue for Airbnb in New York City could involve the following strategies:
#
# * **Increase the availability of listings in neighborhoods with high demand:** Based on the heatmap of availability by neighborhood and room type (Chart 18), hosts can be encouraged to offer more private rooms in Staten Island, which has high availability, and increase the availability of shared rooms in neighborhoods with high demand, such as Manhattan and Brooklyn.
#
# * **Optimize pricing based on availability:** As seen in Chart 16, there is a slight negative correlation between price and availability in 365 days. Therefore, Airbnb can use dynamic pricing strategies to adjust prices based on availability, offering discounts for listings with low availability to increase occupancy and revenue.
#
# * **Focus on recruiting more hosts who offer entire homes or private rooms:** As seen in Chart 19, hosts who offer entire homes or private rooms, such as Dona, Ji, Maya, Carol, and Danielle, are popular among guests. Therefore, Airbnb can focus on recruiting more hosts who offer these types of listings to increase supply and meet customer demand.
#
# * **Expand into underserved neighborhoods:** While Manhattan and Brooklyn have a high concentration of Airbnb listings, other neighborhoods such as the Bronx, Queens, and Staten Island have fewer listings. Airbnb can consider expanding into these underserved neighborhoods to increase supply and meet the needs of customers who may prefer to stay in these areas.
#
# Overall, a combination of these strategies could help Airbnb increase revenue in New York City by increasing supply, optimizing pricing, and improving the user experience for both guests and hosts.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the charts highlighted various insights that can be useful for both Airbnb hosts and guests. The charts provide visual representations of the distribution of Airbnb listings across NYC, the average availability of listings by neighborhood and room type, and the busiest Airbnb hosts based on their listed room types. These insights can help hosts determine where to list their properties and what types of rooms to offer based on demand and availability, and also can help guests choose where to stay based on their preferences and budget.
#
# Additionally, the charts provide some indication of potential correlations between variables, such as the slight negative correlation between price and availability in 365 days. These correlations can help hosts and guests make more informed decisions about pricing and availability.
#
# Overall, these insights can help Airbnb optimize its business strategy, by focusing on recruiting more hosts who offer popular room types, while also diversifying its offerings to mitigate potential negative impacts.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
